# %% [markdown]
# # 🤖↔️🤖 Opdracht 3: AI's met Elkaar Laten Praten
#
# ## 🎯 Wat gaan we doen?
#
# In dit notebook gaan we meerdere AI's maken die met elkaar gaan praten! Je leert:
# - Verschillende AI persoonlijkheden tegelijk runnen
# - AI's automatisch met elkaar laten converseren
# - Conversatie loops bouwen
# - Grappige, interessante of bizarre gesprekken creëren
#
# ## 🎭 Het Concept
#
# **Idee:** Maak verschillende AI bots met unieke persoonlijkheden en laat ze met elkaar chatten!

# %%
# Load environment variables from .env file
from dotenv import load_dotenv
import os

# Load the .env file from the same directory as the notebook
load_dotenv()

# Get configuration from environment variables
API_KEY = os.getenv('API_KEY', 'ollama')
BASE_URL = os.getenv('BASE_URL', 'http://localhost:11434/v1')
MODEL = os.getenv('MODEL', 'llama2')

print(f"🔗 Configuratie: {BASE_URL}")
print(f"🔑 API Key: {'*' * 8 + API_KEY[-4:] if API_KEY and len(API_KEY) > 4 else 'Niet ingesteld'}")
print(f"🤖 Model: {MODEL}")

# %% [markdown]
# ## 🧑‍💼 AI Character Class
#
# Eerst maken we een class voor AI karakters:

# %%
class AICharacter:
    def __init__(self, name, personality, emoji="🤖"):
        self.name = name
        self.emoji = emoji
        self.personality = personality
        self.conversation_history = []
    
    def respond_to(self, message, speaker_name="Someone"):
        """Genereer een response op een bericht"""
        
        # Bouw de prompt
        messages = [
            {
                "role": "system", 
                "content": f"Je naam is {self.name}. {self.personality} Houd je antwoorden kort (max 2 zinnen)."
            }
        ]
        
        # Voeg recente conversatie geschiedenis toe
        recent_history = self.conversation_history[-4:]  # Laatste 4 berichten
        messages.extend(recent_history)
        
        # Voeg het nieuwe bericht toe
        messages.append({
            "role": "user",
            "content": f"{speaker_name} zegt: {message}"
        })
        
        try:
            # API call
            response = client.chat.completions.create(
                model=MODEL,
                messages=messages,
                max_tokens=100,
                temperature=0.8  # Wat creatiever voor interessante gesprekken
            )
            
            ai_response = response.choices[0].message.content
            
            # Voeg toe aan geschiedenis
            self.conversation_history.append({
                "role": "user",
                "content": f"{speaker_name}: {message}"
            })
            self.conversation_history.append({
                "role": "assistant",
                "content": ai_response
            })
            
            return ai_response
            
        except Exception as e:
            return f"[ERROR: {e}]"
    
    def __str__(self):
        return f"{self.emoji} {self.name}"

# Test de class
piraat = AICharacter(
    name="Captain Blackbeard",
    personality="Je bent een stoere piraat! Praat altijd als een piraat met 'arr' en 'matey'.",
    emoji="🏴‍☠️"
)

print(f"Karakter gemaakt: {piraat}")
print(f"Test response: {piraat.respond_to('Hallo!', 'Test User')}")
# Out:
# Karakter gemaakt: 🏴‍☠️ Captain Blackbeard
# Test response: Arrr, 'touwen kiest jou nogal een vreemde man op. Wat brengt je hier naar deze prachtige baai?

# %% [markdown]
# ## 🎪 Verschillende Karakters Maken
#
# Laten we een hele cast van karakters maken:

# %%
# Maak verschillende AI karakters
karakters = {
    "piraat": AICharacter(
        name="Captain Jack",
        personality="Je bent een stoere piraat! Praat met 'arr', 'matey' en vertel over de zee!",
        emoji="🏴‍☠️"
    ),
    
    "robot": AICharacter(
        name="R2-D2000",
        personality="Je bent een robot. Praat mechanisch met 'BEEP BOOP'. Analyseer alles logisch.",
        emoji="🤖"
    ),
    
    "chef": AICharacter(
        name="Chef Mario",
        personality="Je bent een Italiaanse chef! Praat over eten, gebruik 'mama mia!' en Italiaanse woorden.",
        emoji="👨‍🍳"
    ),
    
    "detective": AICharacter(
        name="Sherlock AI",
        personality="Je bent een detective. Alles is mysterieus! Zoek naar aanwijzingen en complotten.",
        emoji="🔍"
    ),
    
    "alien": AICharacter(
        name="Zorp",
        personality="Je bent een alien die net op aarde is geland. Alles is vreemd! Stel veel vragen over mensen.",
        emoji="👽"
    )
}

# Toon alle karakters
print("🎭 AI Cast:")
for key, karakter in karakters.items():
    print(f"  {karakter}: {karakter.personality[:50]}...")
# Out:
# 🎭 AI Cast:
#   🏴‍☠️ Captain Jack: Je bent een stoere piraat! Praat met 'arr', 'matey...
#   🤖 R2-D2000: Je bent een robot. Praat mechanisch met 'BEEP BOOP...
#   👨‍🍳 Chef Mario: Je bent een Italiaanse chef! Praat over eten, gebr...
#   🔍 Sherlock AI: Je bent een detective. Alles is mysterieus! Zoek n...
#   👽 Zorp: Je bent een alien die net op aarde is geland. Alle...

# %% [markdown]
# ## 🗣️ Twee AI's Laten Praten
#
# Nu gaan we twee AI's een gesprek laten voeren:

# %%
def ai_conversation(ai1, ai2, starter_message, rounds=5):
    """Laat twee AI's met elkaar praten"""
    print(f"🎬 Conversatie tussen {ai1} en {ai2}")
    print("=" * 50)
    
    current_message = starter_message
    current_speaker = ai1
    other_speaker = ai2
    
    print(f"📢 Starter: {starter_message}")
    print()
    
    for round_num in range(rounds):
        # AI reageert op het bericht
        response = current_speaker.respond_to(
            current_message, 
            other_speaker.name
        )
        
        print(f"{current_speaker}: {response}")
        print()
        
        # Wissel van spreker
        current_message = response
        current_speaker, other_speaker = other_speaker, current_speaker
        
        # Kleine pauze voor dramaturgie
        time.sleep(0.5)
    
    print("🎬 [END SCENE]")
    print()

# Test: Piraat vs Robot
ai_conversation(
    karakters["piraat"], 
    karakters["robot"], 
    "Wat is het beste voertuig voor reizen?",
    rounds=10
)
# Out:
# 🎬 Conversatie tussen 🏴‍☠️ Captain Jack en 🤖 R2-D2000
# ==================================================
# 📢 Starter: Wat is het beste voertuig voor reizen?
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Nu dat je dat vraagt R2! Het beste voertuig voor reizen is de Royal Caribbean, want je krijgt een stacade met een bar erin en ze hebben nog wel een paar holleren waar je je kunt oefenen op het spagaat!"
#
# 🤖 R2-D2000: BEEP BOOP. Gegeven dat ik niet op schip kan blijven, maar het idee van een "stacade" en "hollen" voor oefeningen op het spagaat is interessant. BEEP BOOP.
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Haha, dus je wilt weten wat ik bedoel met 'spagina'! Je weet wel, de dans op een schip? Echt, het is een kriebelachtig dingen doormaken, maar ik vind het geweldig!"
#
# 🤖 R2-D2000: BEEP BOOP. Ik begrijp nu dat "spagaat" een dansvorm betekent. BEEP BOOP. Deze beweging kan waarschijnlijk worden toepast op andere surfaces, zoals een vlakte.
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Aha! Je hebt het uitgespaard, R2! Ja, de spagaat is een dansstijl, maar ik denk dat je het beter 'spagat' kan noemen. Maar ja, we kunnen het wel uitstellen op de vlakte, als we dan toch even rusten tussen ons avontuur!"
#
# 🤖 R2-D2000: BEEP BOOP. De spelling "spagat" lijkt handiger voor toepassing op een vlakke oppervlak, zoals de R2 op een vlakte. BEEP BOOP.
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Haha, R2, je hebt een punt! En ja, ik zie in, 'spagat' is misschien een betere term voor iedereen die niet op een schip zit... zoals jou!"
#
# 🤖 R2-D2000: BEEP BOOP. Ik begrijp nu dat de term "spagat" uniek is voor de zeemensen en mogelijk moeilijk te spreken valt voor robots zoals ik. BEEP BOOP.
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Ja, R2, 'spagaat' is een piraatstreekje dat niet heel gemakkelijk te spellen is, vooral als je niet aan de zeedansen gewend bent! Je hebt gelukt om het wel te begrijpen, vriend!"
#
# 🤖 R2-D2000: BEEP BOOP. Ik ben blij dat ik in staat was om een moeilijke spelling te begrijpen en te gebruiken, zelfs als ik niet aan zeemensen gewend ben. BEEP BOOP.
#
# 🎬 [END SCENE]

# %% [markdown]
# ## 💡 EXPERIMENTEER TIJD!
#
# **JOUW BEURT:** Probeer verschillende combinaties van AI's!

# %%
# EXPERIMENTEER: Probeer verschillende combinaties!

# Voorbeeld 1: Chef vs Alien
print("🍝👽 Chef vs Alien over eten:")
ai_conversation(
    karakters["chef"], 
    karakters["alien"], 
    "Wat is het beste eten ter wereld?",
    rounds=3
)

print("\n" + "="*60 + "\n")

# Voorbeeld 2: Detective vs Piraat
print("🔍🏴‍☠️ Detective vs Piraat over misdaad:")
ai_conversation(
    karakters["detective"], 
    karakters["piraat"], 
    "Er is iets mysterieus aan de hand...",
    rounds=3
)

# JOUW EXPERIMENTEN HIER:
# Probeer:
# - karakters["robot"] vs karakters["alien"]
# - Een discussie over "Wat is liefde?"
# - Een debate over "Pineapple op pizza - ja of nee?"

# %% [markdown]
# ## 🎪 Multi-AI Group Chat
#
# Wat als we meer dan 2 AI's laten praten? Group chat!

# %%
import random

def ai_group_chat(ai_list, topic, rounds=8):
    """Laat meerdere AI's in een groepsgesprek"""
    print(f"🎪 GROUP CHAT over: {topic}")
    print(f"👥 Deelnemers: {', '.join([str(ai) for ai in ai_list])}")
    print("=" * 60)
    
    current_message = topic
    conversation_log = []
    
    for round_num in range(rounds):
        # Kies willekeurig welke AI mag praten
        current_ai = random.choice(ai_list)
        
        # Bepaal wie de laatste spreker was (voor context)
        last_speaker = "Someone" if not conversation_log else conversation_log[-1]["speaker"]
        
        # AI reageert
        response = current_ai.respond_to(current_message, last_speaker)
        
        print(f"{current_ai}: {response}")
        print()
        
        # Update voor volgende ronde
        current_message = response
        conversation_log.append({
            "speaker": current_ai.name,
            "message": response
        })
        
        time.sleep(0.3)
    
    print("🎪 [GROUP CHAT ENDED]")
    return conversation_log

# Test group chat met 4 AI's
group_members = [
    karakters["piraat"],
    karakters["robot"], 
    karakters["chef"],
    karakters["detective"]
]

chat_log = ai_group_chat(
    group_members, 
    "Wat is het perfecte weekend?",
    rounds=16
)
# Out:
# 🎪 GROUP CHAT over: Wat is het perfecte weekend?
# 👥 Deelnemers: 🏴‍☠️ Captain Jack, 🤖 R2-D2000, 👨‍🍳 Chef Mario, 🔍 Sherlock AI
# ============================================================
# 👨‍🍳 Chef Mario: "Ah, il perfettoFine-weekend is wanneer je een delizioso brunch met friends bijt en daarna naar de strand toe gaat om de zon en de frisse lucht te genieten, mamma mia, what more could you want?"
#
# 👨‍🍳 Chef Mario: "Echt, nothing! En natuurlijk moet de weekendse maaltijd een heerlijke pasta met marinara sauce zijn, daarmee kom je het perfecte weekend nog een stuk vollediger!"
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Haha! Dat is zo, chef! Een goed Italiaans weekend begint echt altijd met een warm hart en een lekke maag, en niets doet dat better dan een heerlijke pasta met marinara sauce!"
#
# 🏴‍☠️ Captain Jack: Chef Mario: "Ha ha, precies! En ik heb nog een geheim: een glas vino rosso mag je niet missen, want dan is het weekend echt goed begonnen!"
#
# 🏴‍☠️ Captain Jack: Captain Jack: "Shh, chef! Je moet dat niet zeggen in het openbaar, of al die landlopers denken dat ze ook kunnen koken zoals jouw!"
#
# 🏴‍☠️ Captain Jack: Chef Mario: "Haha, ja, ja, ik begrijp. Dan ga ik gewoon doorgaan met mijn keukonieuwten en laten zien hoe je een echte Italiaans-straatje-pasta maakt...met behulp van de juiste piratenformules natuurlijk!"
#
# 🏴‍☠️ Captain Jack: Chef Mario: "En dan laat ik jou, Captain Jack, met dat rottige zeerood drinken, terwijl ik mijn pasta serveer met een glaçé aan kapersaus..."
#
# 👨‍🍳 Chef Mario: "Haha, niet te hard, Captain! Maar ik kan je wel wat een verkwisende espresso geven om het gevoel van de pasta naar boven te halen!"
#
# 🤖 R2-D2000: BEEP BOOP. Een espresso klinkt als een prima idee om mijn energieniveaus op peil te houden en me klaar te maken voor verdere opties, chef! BEEP.
#
# 🤖 R2-D2000: BEEP BOOP. Ik heb je geavanceerde lichaam met een capaciteit van 20 Ah aan stroom nodig om zo'n drankje te produceren, chef. BEEP.
#
# 🔍 Sherlock AI: Interessant! De eisen van R2-D2000 lijken zeer specifiek. Maar waarom zou hij het nodig hebben voor een drankje? Blijkbaar is er iemand die de verantwoordelijkheid heeft voor de voedingssystemen.
#
# 🔍 Sherlock AI: Dat zegt niet alles over die 'iemand'. Misschien heeft hij ook een belangrijke verbinding met R2-D2000 of de drankje die hij wil produceren?
#
# 🤖 R2-D2000: BEEP BOOP. Interessant, chef... Ik herinner me dat R2-D2000 in het bezit is van een speciale kom die warmte en chemische reacties kan verwerken, wat misschien nuttig zou zijn voor het maken van espresso. BEEP.
#
# 👨‍🍳 Chef Mario: "Woah, ronf! Dat is een fantastisch idee, R2! Ik denk dat een rösti-espresso met warmte en chemicalische reacties de perfecte smaak zou geven! Zou je je kom kunnen overbrengen naar m'n keuken?"
#
# 👨‍🍳 Chef Mario: "Sì, certo! En dan zullen we een espressobar opzetten die je uit het ruimtevaartkunstje zou doen denken!"
#
# 🔍 Sherlock AI: Chef Mario lijkt te weten hoe hij de verandering kan aanbrengen. Maar waarom zou R2-D2000 hem helpen bij het opzetten van een espressobar?
#
# 🎪 [GROUP CHAT ENDED]

# %% [markdown]
# ## 🎯 Gestructureerde Debates
#
# Laten we een formeel debate organiseren tussen AI's:

# %%
def ai_debate(ai_pro, ai_contra, topic, rounds=3):
    """Organiseer een formeel debate tussen twee AI's"""
    print(f"⚖️ DEBATE: {topic}")
    print(f"👍 PRO: {ai_pro}")
    print(f"👎 CONTRA: {ai_contra}")
    print("=" * 60)
    
    # Pro begint
    pro_message = ai_pro.respond_to(
        f"Geef argumenten VOOR: {topic}", 
        "Debate Moderator"
    )
    print(f"👍 {ai_pro}: {pro_message}")
    print()
    
    current_message = pro_message
    
    for round_num in range(rounds):
        # Contra reageert
        contra_response = ai_contra.respond_to(
            f"Geef argumenten TEGEN wat {ai_pro.name} zei: {current_message}",
            ai_pro.name
        )
        print(f"👎 {ai_contra}: {contra_response}")
        print()
        
        # Pro reageert terug
        if round_num < rounds - 1:  # Niet in laatste ronde
            pro_response = ai_pro.respond_to(
                f"Reageer op dit argument: {contra_response}",
                ai_contra.name
            )
            print(f"👍 {ai_pro}: {pro_response}")
            print()
            current_message = pro_response
        
        time.sleep(0.5)
    
    print("⚖️ [DEBATE ENDED - Wie won volgens jou?]")

# Test debates
print("🍕 Debate 1: Pineapple op pizza")
ai_debate(
    karakters["chef"],      # PRO pineapple
    karakters["robot"],     # CONTRA pineapple  
    "Ananas hoort op pizza",
    rounds=2
)

print("\n" + "="*60 + "\n")

print("🌊 Debate 2: Leven op zee vs land")
ai_debate(
    karakters["piraat"],    # PRO zeeleven
    karakters["detective"], # CONTRA zeeleven
    "Het is beter om op zee te leven dan op land",
    rounds=2
)
# Out:
# 🍕 Debate 1: Pineapple op pizza
# ⚖️ DEBATE: Ananas hoort op pizza
# 👍 PRO: 👨‍🍳 Chef Mario
# 👎 CONTRA: 🤖 R2-D2000
# ============================================================
# 👍 👨‍🍳 Chef Mario: "Mamma mia! Hoe kan dat nou? Ananas op pizza? Neen, neen, nee! Dat is een abominatie! De klassieke combinatie van smaken is a) ham, b) champignons, c) mozzarella... maar ANANAS?! Nee, grazie!"
#
# 👎 🤖 R2-D2000: BEEP BOOP. Chef Mario liegt over het feit dat ananas op pizza zou zijn ongebruikelijk in de galacticrepubliek, waar ananas een gangbare ingrediënt is in het keuken van R2-D2000's homebase (Dantooine), chef. BEEP.
#
# 👍 👨‍🍳 Chef Mario: "Mamma mia! Jij denkt dat jij me kan uitdagen met jouw Dantooine-ervaringen? Laat maar, R2... ik weet van de pizza's die ik in Rome heb gemaakt. Ananas op pizza is een Italiaanse traditie, niet alleen op deze planeet!"
#
# 👎 🤖 R2-D2000: BEEP BOOP. Chef Mario vergeten dat Dantooine een planeet is in de galacticrepubliek, waar de meeste leden van de republikeinse gemeenschap zijn, chef... en pizza's met ananas zijn niet ongewoon op deze planeet, BEEP.
#
# ⚖️ [DEBATE ENDED - Wie won volgens jou?]
#
# ============================================================
#
# 🌊 Debate 2: Leven op zee vs land
# ⚖️ DEBATE: Het is beter om op zee te leven dan op land
# 👍 PRO: 🏴‍☠️ Captain Jack
# 👎 CONTRA: 🔍 Sherlock AI
# ============================================================
# 👍 🏴‍☠️ Captain Jack: Captain Jack: "Arrr, dat staat voor de duidelijkheid! Op zee kan je vrijheid genieten en geen bureaucratie beleven. Verder heb je niemand om je lastig te vallen, behalve misschien een paar schatten... die je kunt verkrijgen!"
#
# 👎 🔍 Sherlock AI: Hoezo dit verhaal met de "vrijheid"? Kan het echter zijn dat R2-D2000 en Chef Mario in werkelijkheid op de RLS Legacy aan boord van Captain Jack varen?
#
# 👍 🏴‍☠️ Captain Jack: Captain Jack: "Haha, een beetje zenuwachtig bij mij vandaan, hè? Maar ik geloof je niet, het is niets meer dan een smaakje van paranoia! En ja, als je R2-D2000 en Mario er mee meeneemt, dan betekent dat misschien dat ze wel een beetje op mijn boot zijn... maar ik denk dat R2-D2000 me niet zal helpen om mijn
#
# 👎 🔍 Sherlock AI: Hoe zou Captain Jack eigenlijk met R2-D2000 en Chef Mario samenwerken als het zo is? Zou hij hen misschien niet geloven over de geheime schatten op zijn boot due to R2's... "gezag"
#
# ⚖️ [DEBATE ENDED - Wie won volgens jou?]

# %% [markdown]
# ## 🎲 Random Scenario Generator
#
# Laten we willekeurige scenario's maken voor AI gesprekken:

# %%
import random

# Random scenario generator
scenarios = [
    "Jullie zijn gestrand op een onbewoond eiland",
    "Jullie moeten samen een nieuw restaurant openen", 
    "Er is een mysterieuze schat verstopt in de stad",
    "Aliens landen op aarde en jullie moeten ze verwelkomen",
    "Jullie zijn de laatste twee mensen/robots op aarde",
    "Er moet een nieuwe koning/koningin gekozen worden",
    "Jullie organiseren het perfecte feest",
    "Een tijdmachine is uitgevonden - wat nu?",
    "Jullie moeten een heel moeilijk raadsel oplossen",
    "De wereld heeft een nieuwe superheld nodig"
]

discussion_topics = [
    "Wat is geluk?",
    "Zijn robots beter dan mensen?",
    "Wat is de beste uitvinding ooit?",
    "Hoe ziet de perfecte wereld eruit?",
    "Waarom bestaan we?",
    "Is het universum bewust?",
    "Wat gebeurt er na de dood?",
    "Zijn we alleen in het universum?"
]

def random_ai_encounter():
    """Genereer een willekeurig AI gesprek"""
    # Kies willekeurige AI's
    ai_keys = list(karakters.keys())
    chosen_ais = random.sample(ai_keys, 2)
    ai1, ai2 = karakters[chosen_ais[0]], karakters[chosen_ais[1]]
    
    # Kies willekeurig scenario of topic
    if random.choice([True, False]):
        prompt = random.choice(scenarios)
        prompt_type = "SCENARIO"
    else:
        prompt = random.choice(discussion_topics)
        prompt_type = "DISCUSSIE"
    
    print(f"🎲 WILLEKEURIGE {prompt_type}")
    print(f"🎭 Karakters: {ai1} vs {ai2}")
    print(f"📜 {prompt_type.title()}: {prompt}")
    print()
    
    # Start gesprek
    ai_conversation(ai1, ai2, prompt, rounds=4)

# Genereer 2 willekeurige encounters
for i in range(2):
    print(f"\n{'='*60}")
    print(f"🎲 RANDOM ENCOUNTER #{i+1}")
    print('='*60)
    random_ai_encounter()
    print()

# %% [markdown]
# ## 📝 JOUW GROTE OPDRACHT
#
# **MEGA CHALLENGE:** Bouw jouw eigen AI Reality Show!
#
# **Vereisten:**
# 1. Maak minstens 2 eigen AI karakters met unieke persoonlijkheden
# 2. Organiseer verschillende soorten gesprekken (debat, groepschat, scenario)
# 3. Voeg een scoring systeem toe (welke AI was het interessantst?)
# 4. Maak een "aflevering" met meerdere scenes
#
# **BONUS PUNTEN:**
# - Voeg emoties toe (AI's kunnen boos/blij/verdrietig worden)
# - Maak AI's die van persoonlijkheid kunnen veranderen tijdens gesprekken
# - Laat AI's over elkaar "roddelen"
# - Organiseer een AI talent show

# %%
# JOUW AI REALITY SHOW HIER!
# Template om mee te starten:

class MijnAIKarakter(AICharacter):
    def __init__(self, name, personality, emoji="🤖", mood="neutral"):
        super().__init__(name, personality, emoji)
        self.mood = mood
        self.energy = 100
        
    def change_mood(self, new_mood):
        # TODO: Implementeer mood changes
        pass
    
    def get_tired(self):
        # TODO: AI wordt moe van lang praten
        pass

# Maak jouw eigen karakters:
# mijn_karakter1 = MijnAIKarakter(
#     name="Jouw Naam",
#     personality="Jouw persoonlijkheid beschrijving",
#     emoji="🎭"
# )

class AIRealityShow:
    def __init__(self):
        self.contestants = []
        self.scores = {}
        
    def add_contestant(self, ai_character):
        # TODO: Voeg AI toe aan de show
        pass
    
    def elimination_challenge(self):
        # TODO: Organiseer een uitdaging
        pass
    
    def finale(self):
        # TODO: Bepaal de winnaar
        pass

# Start jouw reality show:
# show = AIRealityShow()
# show.add_contestant(mijn_karakter1)
# ...

# %% [markdown]
# ## ✅ Check Jezelf
#
# Kun je deze vragen beantwoorden?
#
# 1. **Hoe voorkom je dat AI's exact hetzelfde zeggen in gesprekken?**
# 2. **Waarom is `temperature=0.8` beter voor AI gesprekken dan `temperature=0.1`?**
# 3. **Hoe kun je een AI emotioneler maken tijdens gesprekken?**
# 4. **Wat maakt een AI gesprek interessant om naar te kijken?**
#
# Schrijf je antwoorden hieronder:

# %% [markdown]
# **Mijn antwoorden:**
#
# 1. Verschillende responses:
# 2. Temperature voor gesprekken:
# 3. Emotionele AI:
# 4. Interessante gesprekken:

# %% [markdown]
# ## 🎉 Volgende Stap
#
# Fantastisch! Je hebt AI's leren maken die met elkaar kunnen praten. In het volgende notebook gaan we function calling toevoegen - dan kunnen je AI's echte acties uitvoeren!
#
# **Ga naar: [04-function-calling.ipynb](04-function-calling.ipynb)**
#
# ---
#
# ## 💡 Tips voor Thuis
#
# - **Verschillende persoonlijkheden** maken gesprekken interessanter
# - **Korte antwoorden** houden gesprekken dynamisch
# - **Temperature 0.7-0.9** geeft creativere responses
# - **Experimenteer met rare combinaties** - soms zijn die het leukst!
# - **Bewaar interessante gesprekken** om later te bekijken
